# %%
from mutual_information import mutal_info_from_frame
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import AC

# %% [markdown]
# ### Se obtiene el conjunto de datos

# %%
dataset = pd.read_csv('all_atributes/covid_data_all_atributes.csv')

# %%
dataset.head(3)
# Out:
#            ORIGEN SECTOR        ENTIDAD_UM    SEXO       ENTIDAD_NAC  \
# 0  FUERA DE USMER    SSA  CIUDAD DE MÉXICO  HOMBRE  CIUDAD DE MÉXICO
# 1           USMER    SSA          GUERRERO  HOMBRE          GUERRERO
# 2           USMER    SSA          TLAXCALA   MUJER          TLAXCALA
#
#         ENTIDAD_RES MUNICIPIO_RES  TIPO_PACIENTE  FECHA_INGRESO  \
# 0  CIUDAD DE MÉXICO      ATOLINGA    AMBULATORIO            230
# 1          GUERRERO      PROGRESO  HOSPITALIZADO            153
# 2          TLAXCALA        CALERA    AMBULATORIO            184
#
#    FECHA_SINTOMAS  ... TOMA_MUESTRA_LAB                 RESULTADO_LAB  \
# 0             228  ...              SI       NO POSITIVO A SARS-COV-2
# 1             147  ...              NO   NO APLICA (CASO SIN MUESTRA)
# 2             182  ...              SI       NO POSITIVO A SARS-COV-2
#
#    TOMA_MUESTRA_ANTIGENO            RESULTADO_ANTIGENO         MIGRANTE  \
# ...

# %% [markdown]
# ### Se obtiene y grafica la información mutua entre todos los atributos

# %%
mutual_info = mutal_info_from_frame(dataset, normalize=True)

# %%
fig, axes = AC.createFigures(figsize=(16,12))
sns.heatmap(mutual_info, linewidths=0.5, ax=axes);

# %%
mutual_info.to_csv('informacion_mutua.csv', index=False)
